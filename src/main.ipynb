# %%
from Modeling.preprocessor import *
from Modeling.train import training
import pandas as pd

# %%
df = pd.read_csv('data.csv')
df
# Out:
#                  0           1          2          3          4          5  \
# 0      -378.381226   76.678459  23.239784  13.843393  -5.965930 -34.010609
# 1      -380.143799  100.597214  15.078894   2.440198 -10.985611 -30.110996
# 2      -304.669098  118.192703   2.042840  15.504647  -7.542607 -33.852650
# 3      -308.821411   89.359093  10.470924  28.855902  -3.093584 -32.251301
# 4      -340.816803   59.974323  12.205260  18.845779  -9.285711 -23.310375
# ...            ...         ...        ...        ...        ...        ...
# 127133 -384.777740   50.345749   1.635402  37.339287   2.217140  -7.439549
# 127134 -389.330475   56.802753  -5.907092  33.108158   9.177768 -12.376328
# 127135 -340.107544   46.628071  -0.821079  20.868265  -8.103684  -4.037841
# 127136 -382.290222   46.531910  -7.716600  28.803864   1.719263  -2.526320
# 127137 -383.003265   81.982155 -13.239085  20.035454  -8.921457  -7.344759
#
#                 6          7          8          9  ...       192       193  \
# 0      -32.301823 -12.570757 -12.027764 -16.687765  ...  0.157032  0.271695
# 1      -30.983414 -17.078562 -17.298779 -18.734821  ...  0.138701  0.236866
# 2      -39.650818 -19.708704  -5.323081  -8.056992  ...  0.216409  0.254743
# 3      -31.907427 -18.246683 -12.992827 -23.487600  ...  0.116543  0.299894
# 4      -38.347187 -21.094282 -11.288987 -16.105379  ...  0.151425  0.230372
# ...           ...        ...        ...        ...  ...       ...       ...
# 127133  -7.079442 -10.559595 -16.668497  -1.967378  ...  0.057477  0.097283
# 127134 -11.648993 -13.125114 -19.254459  -3.935121  ...  0.045330  0.088355
# 127135  -5.112887 -12.511058 -17.729290  -0.536883  ...  0.040610  0.097080
# 127136 -14.248698 -10.791382 -11.731325  -1.428563  ...  0.055575  0.097876
# 127137  -0.827834 -15.764476 -27.067240   4.637176  ...  0.041885  0.090290
#
#              194       195       196       197       198        199       200  \
# 0       0.199551  0.092379  0.077370  0.012950  0.070789  16.968049  0.224802
# 1       0.206389  0.088181  0.075871  0.011050  0.108802  16.039196  0.145663
# 2       0.280462  0.094490  0.092035  0.007948  0.058204  19.400424  0.093365
# 3       0.209227  0.093146  0.112789  0.012746  0.069317  19.505548  0.107881
# 4       0.215532  0.085833  0.078073  0.012030  0.095974  15.334975  0.181497
# ...          ...       ...       ...       ...       ...        ...       ...
# 127133  0.088189  0.038923  0.032703  0.024767  0.152487   7.099418  0.230173
# 127134  0.106660  0.032256  0.032898  0.000000  0.000000   0.000000  0.222163
# 127135  0.088076  0.033563  0.039100  0.000000  0.000000   0.000000  0.234091
# 127136  0.090807  0.034271  0.031466  0.030372  0.188592   5.038633  0.233622
# 127137  0.086757  0.030234  0.030142  0.000000  0.000000   0.000000  0.197461
#
#         label
# 0           1
# 1           1
# 2           1
# 3           1
# 4           1
# ...       ...
# 127133      0
# 127134      0
# 127135      0
# 127136      0
# 127137      0
#
# [127138 rows x 202 columns]

# %%
X_train_resampled, y_train_resampled, X_test_transformed, y_test, pipeline = preprocessing(df, 'label')
# Out:
# ✅ Preprocessor pipeline saved to 'D:\College\Third Year\Second Term\Pattern\Project\speaker-gender-age-recognition\src\Modeling\preprocessor.joblib'
# ✅ SMOTE applied to training data

# %%
import joblib
model = joblib.load('./Modeling/classifier.joblib')
model
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=-1,
#               num_parallel_tree=None, ...)

# %%
y_pred = model.predict(X_train_resampled)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_train_resampled, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.85      0.88     70959
#            1       0.91      0.95      0.93     70959
#            2       0.89      0.91      0.90     70959
#            3       0.94      0.92      0.93     70959
#
#     accuracy                           0.91    283836
#    macro avg       0.91      0.91      0.91    283836
# weighted avg       0.91      0.91      0.91    283836

# %%
from xgboost import XGBClassifier

model = XGBClassifier(
    n_estimators=200,
    max_depth=6,
    learning_rate=0.1,
    use_label_encoder=False,
    eval_metric='mlogloss',
    random_state=42,
    n_jobs=-1)

model.fit(X_train_resampled, y_train_resampled)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=200, n_jobs=-1,
#               num_parallel_tree=None, ...)

# %%
y_pred = model.predict(X_train_resampled)
print(classification_report(y_train_resampled, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.93     70959
#            1       0.96      0.98      0.97     70959
#            2       0.94      0.95      0.94     70959
#            3       0.98      0.97      0.97     70959
#
#     accuracy                           0.96    283836
#    macro avg       0.96      0.96      0.96    283836
# weighted avg       0.96      0.96      0.96    283836

# %%
y_pred = model.predict(X_test_transformed)
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.88      0.91     17740
#            1       0.83      0.88      0.86      2697
#            2       0.52      0.68      0.59      2653
#            3       0.80      0.86      0.83      2338
#
#     accuracy                           0.86     25428
#    macro avg       0.77      0.83      0.80     25428
# weighted avg       0.87      0.86      0.86     25428
